# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
# Import Basic Libraries
import numpy as np
import pandas as pd

# Import Datavisualization Libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Set Theme for Data Visualization
# %matplotlib inline
sns.set_style('whitegrid')

# Mitigating Warnings
import warnings
warnings.filterwarnings('ignore')

# Import Libraries for Statistical Analysis
import scipy.stats as stats

# Import Libraries for Train-Test split, Scaling and Metric calculation
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# Import TensorFlow and Keras
import tensorflow as tf
import keras
tf.reset_default_graph()
tf.set_random_seed(40)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
(trainX, trainY), (testX, testY) = keras.datasets.fashion_mnist.load_data()

# %%
print("Train X dimension:",trainX.shape)

print("Train Y dimension:",trainY.shape)

print("Test X dimension:",testX.shape)

print("Test Y dimension:",testY.shape)
# Out:
# Train X dimension: (60000, 28, 28)
# Train Y dimension: (60000,)
# Test X dimension: (10000, 28, 28)
# Test Y dimension: (10000,)

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
# One hot encoding for output label

trainY = tf.keras.utils.to_categorical(trainY, num_classes=10)
testY = tf.keras.utils.to_categorical(testY, num_classes=10)

print("Train Y:",trainY.shape)

print("Test Y:",testY.shape)
# Out:
# Train Y: (60000, 10)
# Test Y: (10000, 10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
#Initialize Sequential model
model = tf.keras.models.Sequential()

#Reshape data from 2D to 1D -> 28x28 to 784
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))

#Normalize the data
model.add(tf.keras.layers.BatchNormalization())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Add 1st hidden layer
model.add(tf.keras.layers.Dense(200, activation='relu'))

#Add 2nd hidden layer
model.add(tf.keras.layers.Dense(100, activation='relu'))

#Dropout Layer
model.add(tf.keras.layers.Dropout(0.25))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Add OUTPUT layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

#Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#Model Execution with epochs = 10 and batch_size = 30
model.fit(trainX, trainY, 
          validation_data=(testX, testY), 
          epochs=10,
          batch_size=30)
# Out:
# Train on 60000 samples, validate on 10000 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 60000/60000 [==============================] - 13s 219us/sample - loss: 0.5171 - acc: 0.8148 - val_loss: 0.3987 - val_acc: 0.8506
# Epoch 2/10
# 60000/60000 [==============================] - 12s 208us/sample - loss: 0.3984 - acc: 0.8557 - val_loss: 0.3904 - val_acc: 0.8535
# Epoch 3/10
# 60000/60000 [==============================] - 12s 201us/sample - loss: 0.3591 - acc: 0.8679 - val_loss: 0.3502 - val_acc: 0.8730
# Epoch 4/10
# 60000/60000 [==============================] - 12s 200us/sample - loss: 0.3373 - acc: 0.8756 - val_loss: 0.3735 - val_acc: 0.8598
# Epoch 5/10
# 60000/60000 [==============================] - 12s 200us/sample - loss: 0.3183 - acc: 0.8816 - val_loss: 0.3493 - val_acc: 0.8740
# Epoch 6/10
# 60000/60000 [==============================] - 12s 201us/sample - loss: 0.3016 - acc: 0.8860 - val_loss: 0.3260 - val_acc: 0.8827
# Epoch 7/10
# 60000/60000 [==============================] - 12s 200us/sample - loss: 0.2894 - acc: 0.8919 - val_loss: 0.3447 - val_acc: 0.8787
# Epoch 8/10
# 60000/60000 [==============================] - 12s 201us/sample - loss: 0.2774 - acc: 0.8961 - val_loss: 0.3541 - val_acc: 0.8793
# Epoch 9/10
# 60000/60000 [==============================] - 12s 199us/sample - loss: 0.2673 - acc: 0.8997 - val_loss: 0.3545 - val_acc: 0.8836
# Epoch 10/10
# 60000/60000 [==============================] - 12s 199us/sample - loss: 0.2550 - acc: 0.9036 - val_loss: 0.3419 - val_acc: 0.8886

# %%
score_train = model.evaluate(trainX, trainY)
score_test = model.evaluate(testX, testY)
print()
print('Training accuracy: ', score_train[1])
print('Test accuracy: ', score_test[1])
# Out:
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.2014 - acc: 0.9247
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.3419 - acc: 0.8886
#
# Training accuracy:  0.92471665
# Test accuracy:  0.8886

# %% [markdown]
# ## Word Embeddings in Python with Gensim

# %% [markdown]
# In this, you will practice how to train and load word embedding models for natural language processing applications in Python using Gensim.

# %% [markdown]
# 1. How to train your own word2vec word embedding model on text data.
# 2. How to visualize a trained word embedding model using Principal Component Analysis.
# 3. How to load pre-trained word2vec word embedding models.

# %% [markdown]
# ### Run the below two commands to install gensim and the wiki dataset

# %%
# !pip3 install --upgrade gensim --user
# Out:
# Requirement already up-to-date: gensim in /root/.local/lib/python3.6/site-packages (3.7.1)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.11.0)
# Requirement already satisfied, skipping upgrade: smart-open>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.8.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.14.6)
# Requirement already satisfied, skipping upgrade: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.7.0->gensim) (2.49.0)
# Requirement already satisfied, skipping upgrade: bz2file in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.7.0->gensim) (0.98)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.7.0->gensim) (2.18.4)
# Requirement already satisfied, skipping upgrade: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.7.0->gensim) (1.9.95)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.7.0->gensim) (2018.11.29)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.7.0->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.7.0->gensim) (2.6)
# Requirement already satisfied, skipping upgrade: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.7.0->gensim) (1.22)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.7.0->gensim) (0.9.3)
# Requirement already satisfied, skipping upgrade: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.7.0->gensim) (0.2.0)
# Requirement already satisfied, skipping upgrade: botocore<1.13.0,>=1.12.95 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.7.0->gensim) (1.12.95)
# Requirement already satisfied, skipping upgrade: docutils>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.95->boto3->smart-open>=1.7.0->gensim) (0.14)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.95->boto3->smart-open>=1.7.0->gensim) (2.5.3)

# %%
# !pip3 install wikipedia --user
# Out:
# Requirement already satisfied: wikipedia in /root/.local/lib/python3.6/site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wikipedia) (2.18.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2018.11.29)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)

# %% [markdown]
# ### Import gensim

# %%
import gensim

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', 
                    level=logging.INFO)

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# ### Obtain Text

# %% [markdown]
# Import search and page functions from wikipedia module
# search(/key word/): search function takes keyword as argument and gives top 10 article titles matching the given keyword.
#
# page(/title of article/): page function takes page title as argument and gives content in the output.

# %%
## Usage: 

from wikipedia import search, page
titles = search("<Key word goes here>")
wikipage = page(titles[0])
print()
print ("Wikipage Content: \n\n",wikipage.content)
# Out:
# Wikipage Content:
#
#  "Here We Go Round the Mulberry Bush" (also titled "Mulberry Bush" or "This Is the Way") is an English nursery rhyme and singing game. It has a Roud Folk Song Index number of 7882. The same tune is also used for "Lazy Mary, Will You Get Up" and "Nuts in May". A variant is used for "The Wheels on the Bus".
#
#
# == Lyrics ==
# The most common modern version of the rhyme is:
#
#
# == Score ==
#
#
# == Origins and meaning ==
# The rhyme was first recorded by James Orchard Halliwell as an English children's game in the mid-19th century. He noted that there was a similar game with the lyrics "Here we go round the bramble bush". The bramble bush may be an earlier version, possibly changed because of the difficulty of the alliteration, since mulberries do not grow on bushes.Halliwell said subsequent verses included: "This is the way we wash our clothes", "This is the way we dry our clothes", "This is the way we mend our shoes", "This is the way the gentlemen walk" and "This is the way the ladies walk.The song and associated game is traditional, and has parallels in Scandinavia and in the Netherlands (the bush is a juniper in Scandinavia).Local historian R. S. Duncan suggests that the song originated with female prisoners at HMP Wakefield. A sprig was taken from Hatfeild Hall (Normanton Golf Club) in Stanley, Wakefield, and grew into a fully mature mulberry tree around which prisoners exercised in the moonlight.The Christmas carol, "As I Sat on a Sunny Bank", collected by Cecil Sharp in Worcestershire, has a very similar melody; as does the related "I Saw Three Ships."Another possible interpretation of the rhyme is that it references Britain's struggles to produce silk, mulberry trees being a key habitat for the cultivation of silkworms. As Bill Bryson explains, Britain in the eighteenth and nineteenth centuries tried to emulate the success of the Chinese in silk production but the industry was held back by periodic harsh winters and mulberry trees proved too sensitive to frost to thrive.   The  traditional lyrics "Here we go round the mulberry bush / On a cold and frosty morning" may therefore be a joke about the problems faced by the industry.
#
#
# == Game and song ==
# The simple game involves holding hands in a circle and moving around to the first verse, which is alternated with the specific verse, where the players break up to imitate various appropriate actions.A variant of this rhyme is "Nuts in May", sharing the tune as well as the traditional closing line "On a cold and frosty morning".
#
#
# == Recordings ==
# In 1938, a song called "Stop Beatin' Round the Mulberry Bush", with lyrics by Bickley Reichner and music by Clay Boland and built around the basic melody of the nursery rhyme, was popular with recordings by bands such as Count Basie, Jack Hylton, Nat Gonella, and Joe Loss. That version became popular again in 1953, when it was recorded by Bill Haley & His Comets.
# A version was recorded in Western Armenian in the 2017 album, My First Armenian Songbook, arranged by Karenn Presti and sung by Stephanie Betjemann.
#
#
# === The Merry-Go-Round ===
# The Merry-Go-Round is a song with the same tune as "Here We Go Round the Mulberry Bush", but some notes are removed. The song tells the story of several children on a merry-go-round that—in a sadistic twist—collapses because so many children are riding it. The circle game that accompanies it is similar to the one for Ring Around the Rosie, as described below.
#
# The verse is usually repeated a second time.
# The circle singing game that accompanies these verses also changes by region, but the most common form consists of participants standing in a circle and holding hands, followed by skipping in one direction as they sing the tune that accompanies these verses. As the word collapsed in the second verse is sung, the group usually falls down into a heap.
#
#
# == See also ==
#
# List of nursery rhymes
# Nuts in May (rhyme)
# The Wheels on the Bus
# Pop Goes the Weasel
#
#
# == Notes ==
#
#
# == External links ==
# A full text

# %% [markdown]
# ### Print the top 10 titles for the keyword `Machine Learning`

# %%
# Top 10 Titles:

titles = search("Machine Learning")
titles
# Out:
# ['Machine learning',
#  'Active learning (machine learning)',
#  'Deep learning',
#  'Boosting (machine learning)',
#  'List of datasets for machine learning research',
#  'Support-vector machine',
#  'Adversarial machine learning',
#  'Learning',
#  'Outline of machine learning',
#  'Weka (machine learning)']

# %% [markdown]
# ### Get the content from the first title from the above obtained 10 titles.

# %%
text = page(titles[0])
text.content
# Out:
# 'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to effectively perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model of sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to perform the task. Machine learning algorithms are used in the applications of email filtering, detection of network intruders, and computer vision, where it is infeasible to develop an algorithm of specific instructions for performing the task. Machine learning is closely related to computational statistics, which focuses on making predictions using computers. The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning. Data mining is a field of study within machine learning, and focuses on exploratory data analysis through unsupervised learning. In its application across business problems, machine learning is also referred to as predictive analytics.\n\n\n== Overview of Machine Learning ==\nThe name machine learning was coined in 1959 by Arthur Samuel. Tom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E." This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms. This follows Alan Turing\'s proposal in his paper "Computing Machinery and Intelligence", in which the question "Can machines think?" is replaced with the question "Can machines do what we (as thinking entities) can do?". In Turing\'s proposal the various characteristics that could be possessed by a thinking machine and the various implications in constructing one are exposed.\n\n\n=== Machine learning tasks ===\n\nMachine learning tasks are classified into several broad categories. In supervised learning, the algorithm builds a mathematical model from a set of data that contains both the inputs and the desired outputs. For example, if the task were determining whether an image contained a certain object, the training data for a supervised learning algorithm would include images with and without that object (the input), and each image would have a label (the output) designating whether it contained the object. In special cases, the input may be only partially available, or restricted to special feedback. Semi-supervised learning algorithms develop mathematical models from incomplete training data, where a portion of the sample input doesn\'t have labels.\nClassification algorithms and regression algorithms are types of supervised learning. Classification algorithms are used when the outputs are restricted to a limited set of values. For a classification algorithm that filters emails, the input would be an incoming email, and the output would be the name of the folder in which to file the email. For an algorithm that identifies spam emails, the output would be the prediction of either "spam" or "not spam", represented by the Boolean values true and false. Regression algorithms are named for their continuous outputs, meaning they may have any value within a range. Examples of a continuous value are the temperature, length, or price of an object.\nIn unsupervised learning, the algorithm builds a mathematical model from a set of data which contains only inputs and no desired output labels. Unsupervised learning algorithms are used to find structure in the data, like grouping or clustering of data points. Unsupervised learning can discover patterns in the data, and can group the inputs into cate ...

# %% [markdown]
# ### Create a list with name `documents` and append all the words in the 10 pages' content using the above 10 titles.

# %%
# Function to Clean Up Text

import re, string

def clean_str(string):
  """
  String cleaning before vectorization
  """
  try:    
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)         
    words = string.strip().lower().split()    
    words = [w for w in words if len(w)>=1]
    return " ".join(words)	
  except:
    return ""

# %%
documents = []
for i in range(0,len(titles)):
  documents.append(clean_str(page(titles[i]).content))

# %%
#List to hold all words in each review
doc_corp = []

#Iterate over each review
for doc in documents:
    doc_corp.append(doc.split(' '))

print(len(doc_corp))
print(doc_corp[0])
# Out:
# 10
# ['machine', 'learning', 'ml', 'is', 'the', 'scientific', 'study', 'of', 'algorithms', 'and', 'statistical', 'models', 'that', 'computer', 'systems', 'use', 'to', 'effectively', 'perform', 'a', 'specific', 'task', 'without', 'using', 'explicit', 'instructions', 'relying', 'on', 'patterns', 'and', 'inference', 'instead', 'it', 'is', 'seen', 'as', 'a', 'subset', 'of', 'artificial', 'intelligence', 'machine', 'learning', 'algorithms', 'build', 'a', 'mathematical', 'model', 'of', 'sample', 'data', 'known', 'as', 'training', 'data', 'in', 'order', 'to', 'make', 'predictions', 'or', 'decisions', 'without', 'being', 'explicitly', 'programmed', 'to', 'perform', 'the', 'task', 'machine', 'learning', 'algorithms', 'are', 'used', 'in', 'the', 'applications', 'of', 'email', 'filtering', 'detection', 'of', 'network', 'intruders', 'and', 'computer', 'vision', 'where', 'it', 'is', 'infeasible', 'to', 'develop', 'an', 'algorithm', 'of', 'specific', 'instructions', 'for', 'performing', 'the', 'task', 'machine', 'learning', 'is', 'closely', 'related', 'to', 'computational', 'statistics', 'which', 'focuses', 'on', 'making', 'predictions', 'using', 'computers', 'the', 'study', 'of', 'mathematical', 'optimization', 'delivers', 'methods', 'theory', 'and', 'application', 'domains', 'to', 'the', 'field', 'of', 'machine', 'learning', 'data', 'mining', 'is', 'a', 'field', 'of', 'study', 'within', 'machine', 'learning', 'and', 'focuses', 'on', 'exploratory', 'data', 'analysis', 'through', 'unsupervised', 'learning', 'in', 'its', 'application', 'across', 'business', 'problems', 'machine', 'learning', 'is', 'also', 'referred', 'to', 'as', 'predictive', 'analytics', 'overview', 'of', 'machine', 'learning', 'the', 'name', 'machine', 'learning', 'was', 'coined', 'in', 'by', 'arthur', 'samuel', 'tom', 'm', 'mitchell', 'provided', 'a', 'widely', 'quoted', 'more', 'formal', 'definition', 'of', 'the', 'algorithms', 'studied', 'in', 'the', 'machine', 'learning', 'field', 'a', 'computer', 'program', 'is', 'said', 'to', 'learn', 'from', 'experience', 'e', 'with', 'respect', 'to', 'some', 'class', 'of', 'tasks', 't', 'and', 'performance', 'measure', 'p', 'if', 'its', 'performance', 'at', 'tasks', 'in', 't', 'as', 'measured', 'by', 'p', 'improves', 'with', 'experience', 'e', 'this', 'definition', 'of', 'the', 'tasks', 'in', 'which', 'machine', 'learning', 'is', 'concerned', 'offers', 'a', 'fundamentally', 'operational', 'definition', 'rather', 'than', 'defining', 'the', 'field', 'in', 'cognitive', 'terms', 'this', 'follows', 'alan', 'turing', 's', 'proposal', 'in', 'his', 'paper', 'computing', 'machinery', 'and', 'intelligence', 'in', 'which', 'the', 'question', 'can', 'machines', 'think', 'is', 'replaced', 'with', 'the', 'question', 'can', 'machines', 'do', 'what', 'we', 'as', 'thinking', 'entities', 'can', 'do', 'in', 'turing', 's', 'proposal', 'the', 'various', 'characteristics', 'that', 'could', 'be', 'possessed', 'by', 'a', 'thinking', 'machine', 'and', 'the', 'various', 'implications', 'in', 'constructing', 'one', 'are', 'exposed', 'machine', 'learning', 'tasks', 'machine', 'learning', 'tasks', 'are', 'classified', 'into', 'several', 'broad', 'categories', 'in', 'supervised', 'learning', 'the', 'algorithm', 'builds', 'a', 'mathematical', 'model', 'from', 'a', 'set', 'of', 'data', 'that', 'contains', 'both', 'the', 'inputs', 'and', 'the', 'desired', 'outputs', 'for', 'example', 'if', 'the', 'task', 'were', 'determining', 'whether', 'an', 'image', 'contained', 'a', 'certain', 'object', 'the', 'training', 'data', 'for', 'a', 'supervised', 'learning', 'algorithm', 'would', 'include', 'images', 'with', 'and', 'without', 'that', 'object', 'the', 'input', 'and', 'each', 'image', 'would', 'have', 'a', 'label', 'the', 'output', 'designating', 'whether', 'it', 'contained', 'the', 'object', 'in', 'special', 'cases', 'the', 'input', 'may', 'be', 'only', 'partially', 'available', 'or', 'restricted', 'to', 'special', 'feedback', 'semi', 'supervised', 'learning', 'algorithms', ...

# %% [markdown]
# ### Build the gensim model for word2vec with by considering all the words with frequency >=1 with embedding size=50

# %%
#Build the model
model = gensim.models.Word2Vec(doc_corp, #Word list
                               min_count=10, #Ignore all words with total frequency lower than this                           
                               workers=4, #Number of CPUs
                               size=50,  #Embedding size
                               window=5, #Maximum Distance between current and predicted word
                               iter=10   #Number of iterations over the text corpus
                              )
# Out:
# 2019-02-24 16:36:43,748 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-02-24 16:36:43,750 : INFO : collecting all words and their counts
# 2019-02-24 16:36:43,752 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-02-24 16:36:43,762 : INFO : collected 4995 word types from a corpus of 33068 raw words and 10 sentences
# 2019-02-24 16:36:43,763 : INFO : Loading a fresh vocabulary
# 2019-02-24 16:36:43,767 : INFO : effective_min_count=10 retains 516 unique words (10% of original 4995, drops 4479)
# 2019-02-24 16:36:43,768 : INFO : effective_min_count=10 leaves 23139 word corpus (69% of original 33068, drops 9929)
# 2019-02-24 16:36:43,772 : INFO : deleting the raw counts dictionary of 4995 items
# 2019-02-24 16:36:43,774 : INFO : sample=0.001 downsamples 66 most-common words
# 2019-02-24 16:36:43,775 : INFO : downsampling leaves estimated 14895 word corpus (64.4% of prior 23139)
# 2019-02-24 16:36:43,777 : INFO : estimated required memory for 516 words and 50 dimensions: 464400 bytes
# 2019-02-24 16:36:43,778 : INFO : resetting layer weights
# 2019-02-24 16:36:43,791 : INFO : training model with 4 workers on 516 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-02-24 16:36:43,806 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:43,812 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:43,813 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:43,820 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:43,821 : INFO : EPOCH - 1 : training on 33068 raw words (14894 effective words) took 0.0s, 549725 effective words/s
# 2019-02-24 16:36:43,842 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:43,846 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:43,850 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:43,853 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:43,854 : INFO : EPOCH - 2 : training on 33068 raw words (14889 effective words) took 0.0s, 548398 effective words/s
# 2019-02-24 16:36:43,864 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:43,875 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:43,881 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:43,882 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:43,884 : INFO : EPOCH - 3 : training on 33068 raw words (14946 effective words) took 0.0s, 581850 effective words/s
# 2019-02-24 16:36:43,904 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:43,905 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:43,912 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:43,915 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:43,916 : INFO : EPOCH - 4 : training on 33068 raw words (14912 effective words) took 0.0s, 522517 effective words/s
# 2019-02-24 16:36:43,931 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:43,940 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:43,941 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:43,947 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:43,948 : INFO : EPOCH - 5 : training on 33068 raw words (14821 effective words) took 0.0s, 501313 effective words/s
# 2019-02-24 16:36:43,968 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:43,972 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:43,978 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:43,979 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:43,980 : INFO : EPOCH - 6 : training on 33068 raw words (14990 effective words) took 0.0s, 548364 effective words/s
# 2019-02-24 16:36:43,995 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:44,001 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:44,010 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:44,014 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:44,015 : INFO : EPOCH - 7 : training on 33068 raw words (14947 effective words) took 0.0s, 527884 effective words/s
# 2019-02-24 16:36:44,043 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:44,047 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:44,048 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:44,050 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:44,051 : INFO : EPOCH - 8 : training on 33068 raw words (14961 effective words) took 0.0s, 508256 effective words/s
# 2019-02-24 16:36:44,067 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:44,082 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:44,083 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:44,085 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:44,086 : INFO : EPOCH - 9 : training on 33068 raw words (14890 effective words) took 0.0s, 522925 effective words/s
# 2019-02-24 16:36:44,104 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-24 16:36:44,109 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-24 16:36:44,111 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-24 16:36:44,118 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-24 16:36:44,119 : INFO : EPOCH - 10 : training on 33068 raw words (14837 effective words) took 0.0s, 560772 effective words/s
# 2019-02-24 16:36:44,121 : INFO : training on a 330680 raw words (149087 effective words) took 0.3s, 454097 effective words/s

# %% [markdown]
# ### Exploring the model

# %%
#Model size
model.wv.syn0.shape
# Out:
# (516, 50)

# %% [markdown]
# #### Check how many words in the model

# %%
# Vocablury of the model
model.wv.vocab
# Out:
# {'a': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b16a0>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc4a8>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcc88>,
#  'above': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073748>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea5f8>,
#  'accuracy': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc6a0>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea5c0>,
#  'activities': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef0f0>,
#  'adaboost': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073c50>,
#  'adaptive': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efda0>,
#  'adversarial': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073b38>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcb38>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea8d0>,
#  'ai': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ead68>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efe48>,
#  'algorithm': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1e48>,
#  'algorithms': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1f28>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef128>,
#  'allows': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9710>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f8fd86982e8>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef5f8>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1a20>,
#  'analysis': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698ba8>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1c18>,
#  'animal': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef1d0>,
#  'animals': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efef0>,
#  'ann': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef208>,
#  'anomaly': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e99e8>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef2b0>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea2b0>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698f98>,
#  'applications': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b15f8>,
#  'applied': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e95c0>,
#  'approach': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eadd8>,
#  'approaches': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc470>,
#  'architectures': <gensim.models.keyedvectors.Vocab at 0x7f8fd80731d0>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1898>,
#  'artificial': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1dd8>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1e80>,
#  'association': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9d30>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698b70>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073b70>,
#  'attacks': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075358>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef400>,
#  'automatic': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073358>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284908>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9fd0>,
#  'backpropagation': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc400>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea630>,
#  'bayesian': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef6d8>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698fd0>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bccc0>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc2e8>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9ba8>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1438>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bce10>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e95f8>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc080>,
#  'bias': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaac8>,
#  'binary': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef5c0>,
#  'biological': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef198>,
#  'boosting': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073ba8>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698f28>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9e80>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc198>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698198>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efdd8>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9390>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f8fd86985f8>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e90f0>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284400>,
#  'categories': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698438>,
#  'categorization': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073c88>,
#  'category': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef588>,
#  'cdot': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073f28>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x7f8fd92845f8>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efe80>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698780>,
#  'classification': <gensim.models.keyedvectors.Vocab at 0x7f9028950588>,
#  'classifier': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9b70>,
#  'classifiers': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073c18>,
#  'cluster': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9358>,
#  'clustering': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea400>,
#  'cnns': <gensim.models.keyedvectors.Vocab at 0x7f8fd80736a0>,
#  'cognitive': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698588>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcd68>,
#  'complexity': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bce48>,
#  'component': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e97f0>,
#  'computational': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1b70>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1828>,
#  'computing': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698cc0>,
#  'concept': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9ef0>,
#  'conditioning': <gensim.models.keyedvectors.Vocab at 0x7f8fd80753c8>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075278>,
#  'conference': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efba8>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcbe0>,
#  'contains': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698d30>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x7f8fd80739b0>,
#  'context': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcb00>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eff98>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x7f8fd80734e0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698c18>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073390>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b15c0>,
#  'dataset': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef9e8>,
#  'datasets': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efa58>,
#  'decision': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9588>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e98d0>,
#  'defined': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9438>,
#  'descent': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073b00>,
#  'desired': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698550>,
#  'detection': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b14a8>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x7f8fd80734a8>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x7f8fd80739e8>,
#  'dictionary': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e97b8>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc5f8>,
#  'dimensional': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9860>,
#  'discovery': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc550>,
#  'displaystyle': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef0b8>,
#  'distance': <gensim.models.keyedvectors.Vocab at 0x7f8fd80730b8>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcba8>,
#  'dnn': <gensim.models.keyedvectors.Vocab at 0x7f8fd80736d8>,
#  'dnns': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073710>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698748>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcd30>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcf60>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc748>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9668>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698278>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284668>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ead30>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef940>,
#  'empirical': <gensim.models.keyedvectors.Vocab at 0x7f8fd80751d0>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073978>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea828>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcdd8>,
#  'et': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efe10>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073780>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9a20>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7f8fe3d658d0>,
#  'examples': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea320>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698400>,
#  'f': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075160>,
#  'factor': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073400>,
#  'feature': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea4a8>,
#  'features': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea588>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698208>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eac50>,
#  'filtering': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b18d0>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea390>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef160>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efac8>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1208>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea7b8>,
#  'formal': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698518>,
#  'frac': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075080>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efb00>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698e80>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaa58>,
#  'functions': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc828>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efc88>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef080>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea898>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcc50>,
#  'generalization': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc908>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcb70>,
#  'generative': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073240>,
#  'genetic': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e94e0>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea780>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc438>,
#  'google': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef898>,
#  'gradient': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efeb8>,
#  'grammar': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073940>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea470>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075208>,
#  'habituation': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075390>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc780>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284898>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef4a8>,
#  'hierarchical': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073198>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef6a0>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698a90>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eac18>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9208>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eafd0>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea6d8>,
#  'humans': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaba8>,
#  'hyperplane': <gensim.models.keyedvectors.Vocab at 0x7f8fd80effd0>,
#  'hyperplanes': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073da0>,
#  'hypothesis': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bce80>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc9b0>,
#  'identify': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9320>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698b38>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284710>,
#  'images': <gensim.models.keyedvectors.Vocab at 0x7f8fd92844e0>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc630>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b13c8>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284860>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc3c8>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073898>,
#  'inductive': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaa90>,
#  'inference': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1fd0>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc2b0>,
#  'input': <gensim.models.keyedvectors.Vocab at 0x7f8fd92845c0>,
#  'inputs': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698e48>,
#  'instance': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9be0>,
#  'instances': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc898>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1d30>,
#  'instructor': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073a90>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1f98>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efbe0>,
#  'interpretation': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073320>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698eb8>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1a58>,
#  'isbn': <gensim.models.keyedvectors.Vocab at 0x7f8fd80752e8>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1ba8>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698c88>,
#  'j': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073160>,
#  'java': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073cf8>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e99b0>,
#  'kernel': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef668>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc048>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1278>,
#  'label': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284a58>,
#  'labeled': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e92e8>,
#  'labels': <gensim.models.keyedvectors.Vocab at 0x7f9028950518>,
#  'lambda': <gensim.models.keyedvectors.Vocab at 0x7f8fd80750b8>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea9b0>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9e10>,
#  'layer': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef390>,
#  'layers': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef358>,
#  'ldots': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073ef0>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x7f8fd86986d8>,
#  'learned': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc518>,
#  'learner': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc668>,
#  'learners': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073be0>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1390>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9b38>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073fd0>,
#  'leq': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073f60>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bca90>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9940>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea3c8>,
#  'linear': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaf28>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073128>,
#  'logic': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc128>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bca20>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc7f0>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9828>,
#  'lstm': <gensim.models.keyedvectors.Vocab at 0x7f8fd80735c0>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698c50>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e2d68>,
#  'machines': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698908>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1748>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc5c0>,
#  'margin': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073048>,
#  'markov': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9550>,
#  'mathcal': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075240>,
#  'mathematical': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1b00>,
#  'matrix': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9160>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x7f8fd80733c8>,
#  'maximum': <gensim.models.keyedvectors.Vocab at 0x7f8fd80730f0>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284470>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bca58>,
#  'medical': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaf98>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073588>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc710>,
#  'methods': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698b00>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efa90>,
#  'minimization': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc7b8>,
#  'minimize': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc940>,
#  'mining': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698940>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1320>,
#  'modeling': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea940>,
#  'models': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b10b8>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698898>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef978>,
#  'multi': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e94a8>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9908>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073860>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9f98>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea978>,
#  'nearest': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073dd8>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073278>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea7f0>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b10f0>,
#  'networks': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaef0>,
#  'neural': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaeb8>,
#  'neurons': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef278>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eab00>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea358>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef2e8>,
#  'nonlinear': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073208>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f9028950550>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc208>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea550>,
#  'object': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284588>,
#  'objects': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9240>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073e48>,
#  'occurs': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075438>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1ac8>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc4e0>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1978>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698390>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef780>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7f8fd92846a0>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efb38>,
#  'optimization': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698be0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b19b0>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b12e8>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef3c8>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea908>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eacf8>,
#  'output': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284320>,
#  'outputs': <gensim.models.keyedvectors.Vocab at 0x7f8fd86985c0>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e91d0>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x7f8fd86989e8>,
#  'parameters': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eff60>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9198>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9ac8>,
#  'pattern': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc240>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef7f0>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1cc0>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698d68>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073ac8>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea860>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9f60>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea438>,
#  'predict': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc8d0>,
#  'prediction': <gensim.models.keyedvectors.Vocab at 0x7f90289503c8>,
#  'predictions': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b16d8>,
#  'predictive': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698da0>,
#  'press': <gensim.models.keyedvectors.Vocab at 0x7f8fd80752b0>,
#  'probabilistic': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaf60>,
#  'probability': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eaa20>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eae10>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x7f8fd86987b8>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea518>,
#  'processing': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e96a0>,
#  'programming': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc160>,
#  'proposed': <gensim.models.keyedvectors.Vocab at 0x7f8fd80737b8>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x7f8fd80732e8>,
#  'query': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efcc0>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef048>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcac8>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efa20>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698dd8>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9978>,
#  'recognition': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc278>,
#  'recognize': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef908>,
#  'reduction': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea4e0>,
#  'references': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efc50>,
#  'regression': <gensim.models.keyedvectors.Vocab at 0x7f90289504a8>,
#  'regularization': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073828>,
#  'reinforcement': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea748>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1358>,
#  'represent': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9a58>,
#  'representation': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc0b8>,
#  'representations': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9630>,
#  'represented': <gensim.models.keyedvectors.Vocab at 0x7f9028950208>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc1d0>,
#  'researchers': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eada0>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcef0>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcfd0>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075048>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef860>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9da0>,
#  'rules': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9d68>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698710>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc358>,
#  'samples': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc978>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9f28>,
#  'scaling': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef630>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc320>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef710>,
#  'security': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075320>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efc18>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1f60>,
#  'selection': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef748>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eab38>,
#  'semantic': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073e80>,
#  'semi': <gensim.models.keyedvectors.Vocab at 0x7f8fd92847f0>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7f8fd86980b8>,
#  'sets': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bccf8>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f8fd86987f0>,
#  'sgn': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073f98>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bceb8>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef828>,
#  'signal': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e90b8>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073550>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea9e8>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efd30>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efd68>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eff28>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e93c8>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eab70>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073470>,
#  'software': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9470>,
#  'solve': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9080>,
#  'solving': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075128>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698e10>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efb70>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcc18>,
#  'spam': <gensim.models.keyedvectors.Vocab at 0x7f90289501d0>,
#  'sparse': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9898>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f8fd92849b0>,
#  'specific': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1eb8>,
#  'speech': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef438>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073668>,
#  'statistical': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1080>,
#  'statistics': <gensim.models.keyedvectors.Vocab at 0x7f8fd9da3be0>,
#  'stimulus': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075400>,
#  'stochastic': <gensim.models.keyedvectors.Vocab at 0x7f8fd80754a8>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9e48>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075470>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1780>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcf28>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eabe0>,
#  'sum': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef320>,
#  'supervised': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698320>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef4e0>,
#  'svm': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef550>,
#  'svms': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef518>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9eb8>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1e10>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698ef0>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9c88>,
#  'task': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1c88>,
#  'tasks': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698470>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7f8fd80efcf8>,
#  'teaching': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073a20>,
#  'technique': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e96d8>,
#  'techniques': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9400>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eac88>,
#  'terms': <gensim.models.keyedvectors.Vocab at 0x7f8fd86988d0>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e92b0>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9a90>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f8fd86986a0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1b38>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1940>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea240>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9780>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eae80>,
#  'theory': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698cf8>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcf98>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea6a0>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea278>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f8fd86989b0>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9cf8>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9b00>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698ac8>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef8d0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc390>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1630>,
#  'tools': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc9e8>,
#  'traditional': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073630>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef9b0>,
#  'trained': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc860>,
#  'training': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1400>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x7f8fd80738d0>,
#  'transformed': <gensim.models.keyedvectors.Vocab at 0x7f8fd80732b0>,
#  'translation': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef470>,
#  'tree': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9c50>,
#  'trees': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9c18>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc6d8>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9048>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7f9028950358>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9518>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9748>,
#  'units': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef240>,
#  'university': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073a58>,
#  'unsupervised': <gensim.models.keyedvectors.Vocab at 0x7f8fd86984e0>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ef7b8>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1668>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1550>,
#  'user': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea710>,
#  'uses': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc588>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1240>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea2e8>,
#  'values': <gensim.models.keyedvectors.Vocab at 0x7f9028950278>,
#  'vapnik': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073d68>,
#  'variable': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9cc0>,
#  'variables': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9dd8>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698a58>,
#  'varphi': <gensim.models.keyedvectors.Vocab at 0x7f8fd80750f0>,
#  'vec': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073908>,
#  'vector': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9128>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073eb8>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7f8fd80735f8>,
#  'vision': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b12b0>,
#  'visual': <gensim.models.keyedvectors.Vocab at 0x7f8fd80e9278>,
#  'vladimir': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073d30>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073080>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698358>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bcda0>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f8fd86983c8>,
#  'weak': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073518>,
#  'weights': <gensim.models.keyedvectors.Vocab at 0x7f8fd80737f0>,
#  'weka': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073cc0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eae48>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f8fe3d65198>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698668>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f9028950240>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b1a90>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7f8fd92842b0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f8fdbc23a58>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f8fd80eacc0>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f8fd80ea668>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f8fd86984a8>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7f8fd8698f60>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f8fd86b19e8>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f8fd86bc0f0>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f8fd9284438>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073438>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x7f8fd8073e10>,
#  'z': <gensim.models.keyedvectors.Vocab at 0x7f8fd8075198>}

# %% [markdown]
# ### Get an embedding for word `SVM`

# %%
model.wv['svm']
# Out:
# array([-0.2417694 , -0.24420615, -0.3270728 ,  0.31636244, -0.38657758,
#         0.10294402,  0.50202876, -0.17660767, -0.2200225 ,  0.06568649,
#        -0.31555796, -0.29176122, -0.05975629, -0.07367154, -0.30786332,
#         0.30076197,  0.4878046 ,  0.01022672,  0.2025485 ,  0.31482974,
#         0.26381558, -0.57566977, -0.00356158,  0.15234452, -0.08887644,
#         0.12094612,  0.31385854,  0.04325441,  0.03915186, -0.4410611 ,
#         0.24488017,  0.14665775, -0.11505769, -0.88124794,  0.37574026,
#        -0.26656982, -0.08072456,  0.04736617,  0.02083592,  0.03923621,
#         0.23763624, -0.16777651,  0.09120493, -0.24866505,  0.2879205 ,
#        -0.3272936 ,  0.04693003,  0.39004165, -0.00408765, -0.13937509],
#       dtype=float32)

# %% [markdown]
# ### Finding most similar words for word `learning`

# %%
model.wv.most_similar('learning')
# Out:
# 2019-02-24 16:36:44,191 : INFO : precomputing L2-norms of word weight vectors
# [('machine', 0.9827715158462524),
#  ('deep', 0.9719343781471252),
#  ('of', 0.9567088484764099),
#  ('algorithms', 0.9424633979797363),
#  ('a', 0.9417915344238281),
#  ('in', 0.9352954626083374),
#  ('artificial', 0.9335716962814331),
#  ('networks', 0.9332436919212341),
#  ('neural', 0.9324018955230713),
#  ('has', 0.9307993054389954)]

# %% [markdown]
# ### Find the word which is not like others from `machine, svm, ball, learning`

# %%
model.doesnt_match("machine svm ball learning".split())
# Out:
# 2019-02-24 16:36:44,205 : WARNING : vectors for words {'ball'} are not present in the model, ignoring these words
# 'svm'

# %% [markdown]
# ### Save the model with name `word2vec-wiki-10`

# %%
model.save('word2vec-wiki-10')
# Out:
# 2019-02-24 16:36:44,219 : INFO : saving Word2Vec object under word2vec-wiki-10, separately None
# 2019-02-24 16:36:44,224 : INFO : not storing attribute vectors_norm
# 2019-02-24 16:36:44,226 : INFO : not storing attribute cum_table
# 2019-02-24 16:36:44,236 : INFO : saved word2vec-wiki-10

# %% [markdown]
# ### Load the model `word2vec-wiki-10`

# %%
#Load model from memory
model = gensim.models.Word2Vec.load('word2vec-wiki-10')
# Out:
# 2019-02-24 16:36:44,242 : INFO : loading Word2Vec object from word2vec-wiki-10
# 2019-02-24 16:36:44,251 : INFO : loading wv recursively from word2vec-wiki-10.wv.* with mmap=None
# 2019-02-24 16:36:44,252 : INFO : setting ignored attribute vectors_norm to None
# 2019-02-24 16:36:44,254 : INFO : loading vocabulary recursively from word2vec-wiki-10.vocabulary.* with mmap=None
# 2019-02-24 16:36:44,257 : INFO : loading trainables recursively from word2vec-wiki-10.trainables.* with mmap=None
# 2019-02-24 16:36:44,258 : INFO : setting ignored attribute cum_table to None
# 2019-02-24 16:36:44,259 : INFO : loaded word2vec-wiki-10
